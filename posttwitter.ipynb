# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Credentials
USERNAME = "Khwahish88762"
PASSWORD = "Khwahish@02"
TWEET_TEXT = "Posting on Twitter using Python & Selenium! 🔥"

# Start Chrome
driver = webdriver.Chrome()

try:
    # Login to Twitter
    driver.get("https://twitter.com/login")
    time.sleep(3)
    
    username = driver.find_element(By.XPATH, "//input[@name='text']")
    username.send_keys(USERNAME)
    username.send_keys(Keys.RETURN)
    time.sleep(2)
    
    password = driver.find_element(By.XPATH, "//input[@name='password']")
    password.send_keys(PASSWORD)
    password.send_keys(Keys.RETURN)
    time.sleep(5)
    
    # Post tweet
    tweet_box = driver.find_element(By.XPATH, "//div[@role='textbox']")
    tweet_box.send_keys(TWEET_TEXT)
    time.sleep(2)
    
    tweet_button = driver.find_element(By.XPATH, "//div[@data-testid='tweetButton']")
    tweet_button.click()
    time.sleep(2)
    
    print("✅ Tweet posted successfully!")
except Exception as e:
    print(f"❌ Error: {e}")
finally:
    driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from selenium import webdriver
#       2 from selenium.webdriver.common.by import By
#       3 from selenium.webdriver.common.keys import Keys
#
# ModuleNotFoundError: No module named 'selenium'

# %%
pip install selenium
# Out:
# ...
#   Using cached selenium-4.34.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# ...
#   Using cached trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached selenium-4.34.0-py3-none-any.whl (9.4 MB)
# Using cached trio-0.30.0-py3-none-any.whl (499 kB)
# Using cached trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# ...
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: attrs
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Setup
username = "Khwahishsi88762"  # Remove '@'
password = "Khwahish@02"
tweet_text = "🚀 Automated Tweet sent via Selenium!"

# Launch Chrome
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
driver = webdriver.Chrome(options=options)

try:
    driver.get("https://twitter.com/i/flow/login")
    time.sleep(3)

    # Enter username/email
    user_input = driver.find_element(By.NAME, "text")
    user_input.send_keys(username)
    user_input.send_keys(Keys.RETURN)
    time.sleep(2)

    # Enter password (may need another username confirm screen)
    try:
        password_input = driver.find_element(By.NAME, "password")
    except:
        username_confirm = driver.find_element(By.NAME, "text")
        username_confirm.send_keys(Keys.RETURN)
        time.sleep(2)
        password_input = driver.find_element(By.NAME, "password")

    password_input.send_keys(password)
    password_input.send_keys(Keys.RETURN)
    time.sleep(5)

    # Compose tweet
    tweet_box = driver.find_element(By.XPATH, '//div[@data-testid="tweetTextarea_0"]')
    tweet_box.click()
    tweet_box.send_keys(tweet_text)
    time.sleep(1)

    # Post tweet
    tweet_btn = driver.find_element(By.XPATH, '//div[@data-testid="tweetButtonInline"]')
    tweet_btn.click()
    print("✅ Tweet posted successfully!")

except Exception as e:
    print("❌ Error:", e)

finally:
    time.sleep(3)
    driver.quit()
# Out:
# ❌ Error: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[name="text"]"}
#   (Session info: chrome=137.0.7151.120); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff6dad9cda5+78885]
# 	GetHandleVerifier [0x0x7ff6dad9ce00+78976]
# 	(No symbol) [0x0x7ff6dab59bca]
# 	(No symbol) [0x0x7ff6dabb0766]
# 	(No symbol) [0x0x7ff6dabb0a1c]
# 	(No symbol) [0x0x7ff6dac04467]
# 	(No symbol) [0x0x7ff6dabd8bcf]
# 	(No symbol) [0x0x7ff6dac0122f]
# 	(No symbol) [0x0x7ff6dabd8963]
# 	(No symbol) [0x0x7ff6daba16b1]
# 	(No symbol) [0x0x7ff6daba2443]
# 	GetHandleVerifier [0x0x7ff6db074eed+3061101]
# 	GetHandleVerifier [0x0x7ff6db06f33d+3037629]
# 	GetHandleVerifier [0x0x7ff6db08e592+3165202]
# 	GetHandleVerifier [0x0x7ff6dadb730e+186766]
# 	GetHandleVerifier [0x0x7ff6dadbeb3f+217535]
# 	GetHandleVerifier [0x0x7ff6dada59b4+114740]
# ...
